# %% [markdown]
# # Us de l'algoritme de Supervised Machine Learning kNN per a la regressió de la qualitat de certs vins

# %% [markdown]
# * German Bueno Lozano
# * Arnau Gonzalez Almirall

# %% [markdown]
# En aquesta primera part del projecte de l'assignatura entrenarem una kNN per a la regressió de la qualitat de certs Vins.
#
# **Justificacio del dataset triat**: La kNN es un algoritme que es basa en distancies euclidies per a fer la clasificacio o regressio de dades. Quan "arriba" una nova dada es busca la menor distancia entre "k" veins. D'aquesta manera podem fer una regressio o qualificacio de les dades.
#
# Amb l'experiencia previa d'haber fet servir la kNN per a clasificacio de imatges amb kNN a l'associacio PUCRA, ens donem conta que contra mes definides queden les clases en el conjunt de train, millor si no, l'algorisme es molt susceptible de confondre clases.

# %%
# !pip install ucimlrepo

# %% [markdown]
# # data exploration

# %% [markdown]
# En aquest cas farem servir la llibreria de la UCI per importar les dades, per sort, ens donen ja directament per una banda la matriu X y per altre el vector y

# %%
import pandas as pd
from ucimlrepo import fetch_ucirepo 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression

# %%
# fetch dataset 
wine_quality = fetch_ucirepo(id=186) 
  
# data (as pandas dataframes) 
X = wine_quality.data.features 
y = wine_quality.data.targets 
  
df=pd.concat([X,y],axis=1)

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# Comprovem com anem de NaN

# %%
df.isnull().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Escalar las características (PCA es sensible a la escala)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# Visualizar los datos transformados con PCA
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=np.array(y), cmap='coolwarm', edgecolors='k')
plt.xlabel('Componente Principal 1')
plt.ylabel('Componente Principal 2')
plt.title('Datos transformados con PCA')
plt.colorbar(label='Valor objetivo')
plt.show()

# %% [markdown]
# *apreciacion*: no hay una gran cantidad de outliers, pero algunos si que se aprecian

# %% [markdown]
# # Entrenament de la kNN per a fer la reggressió

# %% [markdown]
# **Justificacio clau, per mostrar que entenem el concepte:** Perque fem servir X_scaled en train_test_split y no X_PCA?
# 📌 **Per què el PCA no és necessari en aquest cas?**
# 1️⃣ **Poques característiques (11 en total)** → El dataset no és massa gran en dimensions, per tant, **kNN no pateix la "maledicció de la dimensionalitat"**.
# 2️⃣ **No hi ha característiques altament redundants** → Tot i que algunes variables poden estar correlacionades (per exemple, `total sulfur dioxide` i `free sulfur dioxide`), la regressió kNN pot manejar-les sense problemes.
# 3️⃣ **El PCA pot fer que perdis interpretabilitat** → Les components principals **no tenen un significat físic clar** (com `acidity` o `alcohol`), cosa que dificulta la interpretació dels resultats.
# 4️⃣ **kNN ja és un mètode basat en distància** → El PCA transforma les dades en una nova base, cosa que pot canviar la manera en què kNN mesura les distàncies entre punts.
#
# 📌 **Quan podria ser útil el PCA per a Wine Quality**
# ✅ **Si el dataset tingués moltes més variables** → Si en lloc de 11 variables n'hi hagués 50 o 100, el PCA podria ajudar a reduir la dimensionalitat.
# ✅ **Si hi hagués una alta correlació entre moltes característiques** → En aquest cas, el PCA ajudaria a evitar que el model es "distraigués" amb informació redundant.
# ✅ **Si es vol fer una comparació de models** → Pots provar amb i sense PCA i comparar el rendiment.
#
# Exemple on podriem fer PCA si Wine Quality tingues moltes dimensions?:
#
# Un exemple de característiques que poden tenir **alta correlació** en el dataset de **Wine Quality** són:
#
# 🔹 **Diòxid de sofre total (`total_sulfur_dioxide`)** i **Diòxid de sofre lliure (`free_sulfur_dioxide`)** → Com que el **diòxid de sofre lliure** forma part del **diòxid de sofre total**, és molt probable que estiguin fortament correlacionats.
#
# 🔹 **Densitat (`density`)** i **Sucre residual (`residual_sugar`)** → A mesura que augmenta la quantitat de sucre residual en el vi, també pot augmentar la seva densitat.
#
# 🔹 **Acidesa fixa (`fixed_acidity`)** i **Acidesa cítrica (`citric_acid`)** → Alguns tipus de vins amb més acidesa fixa també poden tenir nivells més alts d’àcid cítric, cosa que pot generar una correlació entre aquestes dues variables.
#
# 🔹 **Sulfats (`sulphates`)** i **Diòxid de sofre total (`total_sulfur_dioxide`)** → Ambdós són utilitzats com a conservants en el vi i poden estar relacionats.
#
# Si foa necessari, podriem calcular la **matriu de correlació** del dataset i veure exactament quines variables estan més relacionades! 🚀
#
# Aixo ja ho hem hagut de arribar a fer en altres projectes, pero per 11 dimensions que te el dataset no ho veiem necessari

# %%
#Dividir en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, test_size=0.2, random_state=42)

# %%
def regression(clf, tuning=False):
  clf.fit(X_train, y_train)
  if tuning:
    print('best pars:', clf.best_params_)
  preds = pd.Series(clf.predict(X_test).flatten(),name='preds')
  reals = pd.Series(y_test.values.ravel(), name='target')
  print('mse:', mean_absolute_error(reals,preds))
  print('R2:', r2_score(reals,preds))

# %%
# %%time
pars = {'n_neighbors': [1, 3, 5, 7, 11], 'weights': ['uniform', 'distance']}
regression(GridSearchCV(KNeighborsRegressor(), pars), True)
# Out:
# best pars: {'n_neighbors': 11, 'weights': 'distance'}
# mse: 0.4019431232479584
# R2: 0.4918134935440083
# CPU times: total: 1.45 s
# Wall time: 1.43 s

# %% [markdown]
# com es pot observar, no obtenim una gran regressió (r^2 baixa) tot i haber fet servir GridSearchCV, anem a provar amb altres metodes

# %%
regression(LinearRegression())
# Out:
# mse: 0.5658710079723465
# R2: 0.25976731297713973

# %% [markdown]
# ## Justificacio del baix R^2

# %% [markdown]
# ### 1. **Elecció del model (kNN i Linear Regression)**
#    - **kNN:** Tot i que kNN pot ser eficaç per a algunes tasques de regressió, no sempre és el model més adequat per a tots els conjunts de dades. És sensible a la selecció del valor de \( k \), el qual pot afectar significativament els resultats. Si \( k \) és massa petit, el model pot sobreajustar-se (overfitting), mentre que si és massa gran, el model pot ser massa simple (underfitting).
#    - **Linear Regression:** Aquest model assumeix que la relació entre les característiques i la variable objectiu és lineal. Si les relacions no són lineals, Linear Regression no serà capaç de capturar la complexitat del conjunt de dades, el que pot resultar en un \( R^2 \) baix.
#
# ### 2. **Selecció de característiques**
#    Tot i que s'ha indicat que s'han conservat totes les dimensions, és important verificar si totes les característiques són realment rellevants per a la predicció de la qualitat del vi. Algunes característiques poden ser irrellevants o redundants. L'ús de tècniques de selecció de característiques, com *SelectKBest* o *PCA* (Anàlisi de Components Principals), pot ajudar a millorar el rendiment mitjançant la reducció de la dimensionalitat.
#
# ### 3. **Hiperparàmetres de kNN**
#    El rendiment de kNN depèn en gran mesura de la selecció del valor de \( k \) i de la mètrica de distància utilitzada. Si \( k \) és massa petit, el model pot ser excessivament sensible al soroll, mentre que si és massa gran, pot perdre informació important.
#    - Es recomana utilitzar validació creuada per determinar el valor òptim de \( k \).
#    - Provar diferents mètriques de distància, com *Euclidean*, *Manhattan* o *Minkowski*, pot millorar el rendiment.
#
# ### 4. **Escalat de dades**
#    Tot i que s'ha utilitzat un escalador estàndard, és important tenir en compte que kNN és molt sensible a l'escalat de les característiques, ja que es basen en el càlcul de distàncies entre punts. Si les dades no estan escalades correctament, les distàncies potser no reflectiran adequadament la relació entre les mostres.
#
#    Per a Linear Regression, l'escalat de les dades no és tan crític, però és recomanable per comparar models i obtenir una millor interpretació dels coeficients.
#
# ### 5. **Distribució de les dades i sorolls**
#    En el conjunt de dades de "Wine Quality", la distribució de la variable objectiu (qualitat del vi) pot estar esbiaixada o pot presentar una variabilitat difícil de modelar. Si la qualitat del vi té una distribució no lineal o està massa dispersa, pot resultar difícil per a kNN i Linear Regression modelar adequadament aquesta variabilitat.
#
#    **Recomanacions**:
#    - **Revisar la distribució de la variable objectiu**. Si està esbiaixada, una transformació (com un logaritme o una normalització) podria millorar els resultats.
#    - **Eliminació o tractament del soroll**. Les dades podrien contenir errors o valors atípics que afecten el rendiment del model. És aconsellable realitzar anàlisis per identificar valors atípics o utilitzar tècniques de detecció de valors anòmals.
#
# ### 6. **Model de base per a la comparació**
#    Un \( R^2 \) de 0.49 no és necessàriament dolent, depenent de la comparació amb un model de referència. Per exemple, un model senzill que predigui la mitjana de la variable objectiu per a totes les mostres podria servir com a base, i si el model no millora significativament sobre aquest punt de partida, pot ser necessari explorar altres enfocaments (com arbres de decisió, Random Forest, o mètodes de boosting).
#
# ### Passos per millorar el model:
# 1. **Optimitzar el valor de \( k \) en kNN** mitjançant validació creuada.
# 2. **Valorar si la relació entre les característiques i la variable objectiu és lineal**, i en cas contrari, provar models més complexos com Random Forest, Gradient Boosting, o Support Vector Machines (SVM).
# 3. **Revisar la selecció de característiques** per eliminar variables irrellevants o altament correlacionades.
# 4. **Considerar transformacions de la variable objectiu** si la distribució de la mateixa és esbiaixada.
# 5. **Comprovar el comportament del model amb altres tècniques d'escalat**, com Min-Max Scaling o Robust Scaling.
#
# Si els problemes persisteixen, es podria intentar amb models més complexos que puguin capturar relacions no lineals, com un **Random Forest Regressor** o un **Gradient Boosting Regressor**.
